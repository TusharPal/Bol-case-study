# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# # Load data

# %%
data = pd.read_csv('../data/clickdata.csv')

data.head()
# Out:
#         epoch_ms                        session_id country_by_ip_address  \
# 0  1520280001034  be73c8d1b836170a21529a1b23140f8e                    US
# 1  1520280001590  c24c6637ed7dcbe19ad64056184212a7                    US
# 2  1520280002397  ee391655f5680a7bfae0019450aed396                    IT
# 3  1520280002598  f8c8a696dd37ca88233b2df096afa97f                    US
# 4  1520280004428  f8b0c06747b7dd1d53c0932306bd04d6                    US
#
#   region_by_ip_address                             url_without_parameters  \
# 0                   CA  https://www.bol.com/nl/l/nederlandstalige-kuns...
# 1                   CA  https://www.bol.com/nl/l/italiaans-natuur-wete...
# 2                   LI  https://www.bol.com/nl/p/nespresso-magimix-ini...
# 3                   CA  https://www.bol.com/nl/l/nieuwe-engelstalige-o...
# 4                   CA  https://www.bol.com/nl/l/nieuwe-actie-avontuur...
#
#                          referrer_without_parameters visitor_recognition_type  \
# 0                                                NaN                ANONYMOUS
# 1                                                NaN                ANONYMOUS
# 2  https://www.bol.com/nl/p/nespresso-magimix-ini...                ANONYMOUS
# 3                                                NaN                ANONYMOUS
# 4                                                NaN                ANONYMOUS
#
#   ua_agent_class
# 0          Robot
# 1          Robot
# 2        Browser
# 3          Robot
# 4   Robot Mobile

# %% [markdown]
# ## Preprocess/create features

# %%
# Filling in missing values
data.loc[data['country_by_ip_address'].isna(), 'country_by_ip_address'] = 'UNK'
data.loc[data['region_by_ip_address'].isna(), 'region_by_ip_address'] = 'UNK'
data.loc[data['referrer_without_parameters'].isna(), 'referrer_without_parameters'] = ''

# Splitting class into class and source
data.loc[data['ua_agent_class'] == 'Browser Webview', 'ua_source'] = 'Webview'
data.loc[data['ua_agent_class'] == 'Browser Webview', 'ua_agent_class'] = 'Browser'
data.loc[data['ua_agent_class'] == 'Robot Mobile', 'ua_source'] = 'Mobile'
data.loc[data['ua_agent_class'] == 'Robot Mobile', 'ua_agent_class'] = 'Robot'

# Getting a url sub class. This is a placeholder for the detailed url breakdown
data['url_subclass'] = data['url_without_parameters'].apply(lambda url: url.removeprefix('https://www.bol.com/nl/').split('/')[0])

data.head()
# Out:
#         epoch_ms                        session_id country_by_ip_address  \
# 0  1520280001034  be73c8d1b836170a21529a1b23140f8e                    US
# 1  1520280001590  c24c6637ed7dcbe19ad64056184212a7                    US
# 2  1520280002397  ee391655f5680a7bfae0019450aed396                    IT
# 3  1520280002598  f8c8a696dd37ca88233b2df096afa97f                    US
# 4  1520280004428  f8b0c06747b7dd1d53c0932306bd04d6                    US
#
#   region_by_ip_address                             url_without_parameters  \
# 0                   CA  https://www.bol.com/nl/l/nederlandstalige-kuns...
# 1                   CA  https://www.bol.com/nl/l/italiaans-natuur-wete...
# 2                   LI  https://www.bol.com/nl/p/nespresso-magimix-ini...
# 3                   CA  https://www.bol.com/nl/l/nieuwe-engelstalige-o...
# 4                   CA  https://www.bol.com/nl/l/nieuwe-actie-avontuur...
#
#                          referrer_without_parameters visitor_recognition_type  \
# 0                                                                   ANONYMOUS
# 1                                                                   ANONYMOUS
# 2  https://www.bol.com/nl/p/nespresso-magimix-ini...                ANONYMOUS
# 3                                                                   ANONYMOUS
# 4                                                                   ANONYMOUS
#
#   ua_agent_class ua_source url_subclass
# 0          Robot       NaN            l
# 1          Robot       NaN            l
# 2        Browser       NaN            p
# 3          Robot       NaN            l
# 4          Robot    Mobile            l

# %% [markdown]
# ## Parse URLs

# %%
def parse_url(url, prefix = 'https://www.bol.com/nl/'):
    def is_product_code(x):
        pass

    url_components = url.removeprefix(prefix).split('/')
    row = {
        'url_function': '',
        'category': '',
        'category_code': '',
        'product_code': '',
        'filters': [],
        'sub_filters': [],
        'other': ''
    }

    index = 0

    if url_components[index] == 'c':
        row['url_function'] = url_components[index]
        index += 1

        if url_components[index] == 'ajax':
            row['other'] = url_components[index]
            index += 1

            if url_components[index] == 'index.html':
                row['other'] += url_components[index]

        else:
            row['category'] = url_components[index]
            index += 1

            while(index < len(url_components)):
                if url_components[index].isdigit():
                    row['category_code'] = url_components[index]
                    index += 1
                    break
                else:
                    row['category'] = row['category'] + '/' + url_components[index]
                    index += 1

    elif url_components[index] == 'checkout':
        row['url_function'] = url_components[index]
        index += 1
        
        row['other'] = url_components[index]

    elif url_components[index] == 'order':
        row['url_function'] = url_components[index]
        index += 1
        
        row['other'] = url_components[index]

    elif url_components[0] == 'p':
        row['url_function'] = url_components[0]
        row['category'] = url_components[1]
        row['product_code'] = url_components[2]

    elif url_components[0] == 'l':
        row['url_function'] = url_components[0]
        row['category'] = url_components[1]

        i = 2
        if len(url_components) >= 4:
            if url_components[2] == 'N':
                row['filters'] = url_components[3].split('+')

                if len(url_components) >= 6:
                    if url_components[4] == 'filter_N':
                        row['sub_filters'] = url_components[5].split('+')

        elif url_components[1] == 'ajax':
            row['other'] += url_components[1]

            if url_components[2] == 'index.html':
                row['other'] += url_components[2]

    return pd.Series(row)

# %%
url_features = ['url_function', 'category', 'category_code', 'product_code', 'filters', 'sub_filters', 'other']
data[url_features] = data['url_without_parameters'].apply(lambda url: parse_url(url))

data.head()
# Out:
#         epoch_ms                        session_id country_by_ip_address  \
# 0  1520280001034  be73c8d1b836170a21529a1b23140f8e                    US
# 1  1520280001590  c24c6637ed7dcbe19ad64056184212a7                    US
# 2  1520280002397  ee391655f5680a7bfae0019450aed396                    IT
# 3  1520280002598  f8c8a696dd37ca88233b2df096afa97f                    US
# 4  1520280004428  f8b0c06747b7dd1d53c0932306bd04d6                    US
#
#   region_by_ip_address                             url_without_parameters  \
# 0                   CA  https://www.bol.com/nl/l/nederlandstalige-kuns...
# 1                   CA  https://www.bol.com/nl/l/italiaans-natuur-wete...
# 2                   LI  https://www.bol.com/nl/p/nespresso-magimix-ini...
# 3                   CA  https://www.bol.com/nl/l/nieuwe-engelstalige-o...
# 4                   CA  https://www.bol.com/nl/l/nieuwe-actie-avontuur...
#
#                          referrer_without_parameters visitor_recognition_type  \
# 0                                                                   ANONYMOUS
# 1                                                                   ANONYMOUS
# 2  https://www.bol.com/nl/p/nespresso-magimix-ini...                ANONYMOUS
# 3                                                                   ANONYMOUS
# 4                                                                   ANONYMOUS
#
#   ua_agent_class ua_source url_subclass url_function  \
# 0          Robot       NaN            l            l
# 1          Robot       NaN            l            l
# 2        Browser       NaN            p            p
# 3          Robot       NaN            l            l
# 4          Robot    Mobile            l            l
#
#                                             category category_code  \
# 0  nederlandstalige-kunstgeschiedenis-theorie-ove...
# 1  italiaans-natuur-wetenschap-kinderboeken-over-...
# 2  nespresso-magimix-inissia-m105-koffiemachine-grey
# 3  nieuwe-engelstalige-outdoor-sportboeken-algeme...
# 4         nieuwe-actie-avontuur-over-prive-detective
#
#        product_code                                            filters  \
# 0                                                  [2324, 24596, 8293]
# 1                                          [24435, 26558, 24670, 7419]
# 2  9200000025533140                                                 []
# 3                    [2806, 4292595594, 4288403245, 4288398652, 140...
# 4                                                 [33590, 26931, 7289]
#
#     sub_filters other
# 0            []
# 1            []
# 2            []
# 3  [4273962351]
# 4            []

# %% [markdown]
# # OG model

# %%
X = pd.get_dummies(data=data[['country_by_ip_address', 'region_by_ip_address', 'visitor_recognition_type']], drop_first=True)
y = data['ua_agent_class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

clf = KNeighborsClassifier(n_jobs=-1)

clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, labels=clf.classes_, zero_division=0.0))
# Out:
#                    precision    recall  f1-score   support
#
#           Browser       0.98      0.99      0.98      9328
# Cloud Application       0.00      0.00      0.00         1
#            Hacker       0.00      0.00      0.00       294
#        Mobile App       0.00      0.00      0.00         2
#             Robot       0.94      0.99      0.97      5285
#           Special       0.67      0.06      0.10        36
#
#          accuracy                           0.97     14946
#         macro avg       0.43      0.34      0.34     14946
#      weighted avg       0.95      0.97      0.96     14946

# %% [markdown]
# ## With url_subclass

# %%
X = pd.get_dummies(data=data[['country_by_ip_address', 'region_by_ip_address', 'visitor_recognition_type', 'url_subclass']], drop_first=True)
y = data['ua_agent_class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

clf = KNeighborsClassifier(n_jobs=-1)

clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, labels=clf.classes_, zero_division=0.0))
# Out:
#                    precision    recall  f1-score   support
#
#           Browser       0.98      0.99      0.99      9328
# Cloud Application       0.00      0.00      0.00         1
#            Hacker       0.28      0.14      0.19       294
#        Mobile App       0.00      0.00      0.00         2
#             Robot       0.96      0.98      0.97      5285
#           Special       1.00      0.06      0.11        36
#
#          accuracy                           0.97     14946
#         macro avg       0.54      0.36      0.37     14946
#      weighted avg       0.96      0.97      0.96     14946

# %% [markdown]
# # With URL features

# %%
X = pd.get_dummies(data=data[['country_by_ip_address', 
                                'region_by_ip_address', 
                                'visitor_recognition_type',
                                'url_function', 
                                'category', 
                                'category_code', 
                                'product_code', 
                                'other']], drop_first=True)
y = data['ua_agent_class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

clf = KNeighborsClassifier(n_jobs=-1)

clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
y_pred = clf.predict(X_test[:10])
# print(classification_report(y_test, y_pred, labels=clf.classes_, zero_division=0.0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 y_pred = clf.predict(X_test[:10])
#       2 # print(classification_report(y_test, y_pred, labels=clf.classes_, zero_division=0.0))
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:274, in KNeighborsClassifier.predict(self, X)
#     271         return self.classes_[np.argmax(probabilities, axis=1)]
#     272     # In that case, we do not need the distances to perform
#     273     # the weighting so we do not compute them.
# --> 274     neigh_ind = self.kneighbors(X, return_distance=False)
#     275     neigh_dist = None
#     276 else:
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/neighbors/_base.py:906, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     903     else:
#     904         kwds = self.effective_metric_params_
# --> 906     chunked_results = list(
#     907         pairwise_distances_chunked(
#     908             X,
#     909             self._fit_X,
#     910             reduce_func=reduce_func,
#     911             metric=self.effective_metric_,
#     912             n_jobs=n_jobs,
#     913             **kwds,
#     914         )
#     915     )
#     917 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     918     if issparse(X):
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:2240, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2238 else:
#    2239     X_chunk = X[sl]
# -> 2240 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2241 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2242     metric, None
#    2243 ) is euclidean_distances:
#    2244     # zeroing diagonal, taking care of aliases of "euclidean",
#    2245     # i.e. "l2"
#    2246     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:2476, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, ensure_all_finite, **kwds)
#    2473         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2474     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2476 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1965, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1963 fd = delayed(_dist_wrapper)
#    1964 ret = np.empty((X.shape[0], Y.shape[0]), dtype=dtype, order="F")
# -> 1965 Parallel(backend="threading", n_jobs=n_jobs)(
#    1966     fd(func, ret, s, X, Y[s], **kwds)
#    1967     for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs))
#    1968 )
#    1970 if (X is Y or Y is None) and func is euclidean_distances:
#    1971     # zeroing diagonal for euclidean norm.
#    1972     # TODO: do it also for other norms.
#    1973     np.fill_diagonal(ret, 0)
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)
#      80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/anaconda3/envs/bol/lib/python3.10/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)
#    1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)
#    1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:
